# %% [markdown]
# <div style="color:#006666; padding:0px 10px; border-radius:5px; font-size:18px;"><h1 style='margin:10px 5px'>Handling Large Data</h1>
# </div>
#
# © Copyright Machine Learning Plus

# %% [markdown]
#  <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>1. Sampling and Subsetting on Load</h2>
# </div>

# %% [markdown]
# __When to use__
#
# You have a large dataframe and you need only a smaller portion of the rows sampled randomly. Sometimes you might want only select columns from it.
#
# In such case, you can avoid loading the entire dataframe and then sampling from it, by using `skiprows` to let `read_csv` know which rows to skip.
#
# It accepts a function as an argument, using which you can randomize the rows being read.
#
# __Why__
#
# Doing these techniques will reduce the memory required to hold the data, allowing you to accomodate larger datasets in the limited memory.

# %%
import numpy as np
import pandas as pd

# %%
# read only random 10% of the rows.
df = pd.read_csv('Datasets/large_dataset.csv', 
                 skiprows=lambda x: x != 0 and np.random.rand() > 0.01)
df.head()
# Out:
#    HasTpm  Census_OSInstallLanguageIdentifier  LocaleEnglishNameIdentifier  \
# 0       1                            0.356200                      0.23470
# 1       1                            0.116000                      0.03827
# 2       1                            0.014786                      0.01521
# 3       1                            0.048460                      0.23470
# 4       1                            0.057340                      0.04608
#
#    EngineVersion  UacLuaenable  Census_MDC2FormFactor  \
# 0        0.41190             0                      1
# 1        0.43100             0                      1
# 2        0.41190             0                      0
# 3        0.02391             0                      5
# 4        0.41190             0                      1
#
#    Census_IsSecureBootEnabled  Census_OSVersion  Census_GenuineStateName  \
# 0                           0          0.036440                        0
# 1                           0          0.024280                        0
# 2                           0          0.024280                        0
# 3                           1          0.100900                        0
# 4                           1          0.000676                        0
#
#    Census_InternalPrimaryDisplayResolutionHorizontal  RtpStateBitfield  \
# 0                                             1366.0                 0
# 1                                             1366.0                 0
# 2                                             1920.0                 0
# 3                                             1366.0                 0
# 4                                             1366.0                 0
#
#    Census_ActivationChannel  GeoNameIdentifier  Census_OSUILocaleIdentifier  \
# 0                         0           0.171800                     0.355500
# 1                         0           0.038850                     0.116700
# 2                         0           0.015360                     0.014824
# 3                         2           0.000353                     0.048920
# 4                         2           0.033230                     0.057500
#
#    Census_OSEdition  AVProductsInstalled  \
# 0                 0                  1.0
# 1                 1                  2.0
# 2                 0                  1.0
# 3                 1                  1.0
# 4                 0                  1.0
#
#    Census_FirmwareManufacturerIdentifier  Census_OEMNameIdentifier  \
# 0                                0.10547                   0.10630
# 1                                0.04330                   0.10380
# 2                                0.30250                   0.03476
# 3                                0.13170                   0.11640
# 4                                0.01197                   0.11640
#
#    Census_SystemVolumeTotalCapacity  Census_OSVersion_0
# 0                           37974.0                   0
# 1                          694454.0                   0
# 2                          113971.0                   0
# 3                          937177.0                   0
# 4                          934026.0                   0

# %%
df.shape
# Out:
# (9895, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9895 entries, 0 to 9894
# Data columns (total 20 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   HasTpm                                             9895 non-null   int64
#  1   Census_OSInstallLanguageIdentifier                 9813 non-null   float64
#  2   LocaleEnglishNameIdentifier                        9895 non-null   float64
#  3   EngineVersion                                      9895 non-null   float64
#  4   UacLuaenable                                       9895 non-null   int64
#  5   Census_MDC2FormFactor                              9895 non-null   int64
#  6   Census_IsSecureBootEnabled                         9895 non-null   int64
#  7   Census_OSVersion                                   9895 non-null   float64
#  8   Census_GenuineStateName                            9895 non-null   int64
#  9   Census_InternalPrimaryDisplayResolutionHorizontal  9838 non-null   float64
#  10  RtpStateBitfield                                   9895 non-null   int64
#  11  Census_ActivationChannel                           9895 non-null   int64
#  12  GeoNameIdentifier                                  9894 non-null   float64
#  13  Census_OSUILocaleIdentifier                        9895 non-null   float64
#  14  Census_OSEdition                                   9895 non-null   int64
#  15  AVProductsInstalled                                9847 non-null   float64
#  16  Census_FirmwareManufacturerIdentifier              9674 non-null   float64
#  17  Census_OEMNameIdentifier                           9804 non-null   float64
#  18  Census_SystemVolumeTotalCapacity                   9839 non-null   float64
#  19  Census_OSVersion_0                                 9895 non-null   int64
# dtypes: float64(11), int64(9)
# memory usage: 1.5 MB

# %% [markdown]
# Additionally you can specify only the columns you want to read in, so the other columns won't be loaded to save memory.

# %%
# %%time

# specify the columns: 
df = pd.read_csv('Datasets/large_dataset.csv', 
                 skiprows=lambda x: x != 0 and np.random.rand() > 0.01,
                 usecols=['HasTpm', 'GeoNameIdentifier', 'RtpStateBitfield'])
df.head()
# Out:
# Wall time: 1.68 s
#    HasTpm  RtpStateBitfield  GeoNameIdentifier
# 0       1                 0            0.00949
# 1       0                 0            0.01823
# 2       1                 0            0.03867
# 3       1                 0            0.01823
# 4       1                 0            0.17180

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10028 entries, 0 to 10027
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   HasTpm             10028 non-null  int64
#  1   RtpStateBitfield   10028 non-null  int64
#  2   GeoNameIdentifier  10026 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 235.2 KB

# %% [markdown]
# __Mention the datatypes as well to bring down the memory consumption further.__

# %% [markdown]
# First, let's check what sort of datatypes are required to hold the data.

# %%
df.describe()

# %%
# specify the columns: 
df = pd.read_csv('Datasets/large_dataset.csv', 
                 skiprows=lambda x: x != 0 and np.random.rand() > 0.01,
                 usecols=['HasTpm', 'GeoNameIdentifier', 'RtpStateBitfield'],
                 dtype={'HasTpm':'bool', 'GeoNameIdentifier':np.float16, 'RtpStateBitfield':np.int8})

df.head()
# Out:
#    HasTpm  RtpStateBitfield  GeoNameIdentifier
# 0    True                 0           0.038849
# 1    True                 0           0.038849
# 2    True                 0           0.012543
# 3    True                 0           0.018234
# 4    True                 0           0.006493

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10067 entries, 0 to 10066
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   HasTpm             10067 non-null  bool
#  1   RtpStateBitfield   10067 non-null  int8
#  2   GeoNameIdentifier  10067 non-null  float16
# dtypes: bool(1), float16(1), int8(1)
# memory usage: 39.4 KB

# %% [markdown]
#  <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>2. Efficient File Formats</h2>
# </div>
#
#  __When to use__
#
#  When the file size is large and stored in legacy data formats such as .csv or excel files, it could take more space in disk and consumes more time to read and write data.
#
#  You can do better using modern file formats to save data such as:
#  1. feather
#  2. parquet

# %%
# !pip install pyarrow

# %%
# %%time
df = pd.read_csv('Datasets/large_dataset.csv')
df.head()
# Out:
# Wall time: 2.77 s
#    HasTpm  Census_OSInstallLanguageIdentifier  LocaleEnglishNameIdentifier  \
# 0       1                              0.1160                     0.010284
# 1       1                              0.3562                     0.234700
# 2       1                              0.3562                     0.234700
# 3       1                              0.3562                     0.234700
# 4       1                              0.1160                     0.037380
#
#    EngineVersion  UacLuaenable  Census_MDC2FormFactor  \
# 0        0.41190             0                      1
# 1        0.43100             0                      1
# 2        0.02974             0                      1
# 3        0.41190             0                      1
# 4        0.41190             0                      0
#
#    Census_IsSecureBootEnabled  Census_OSVersion  Census_GenuineStateName  \
# 0                           1          0.039000                        0
# 1                           0          0.158400                        0
# 2                           0          0.023130                        2
# 3                           0          0.036440                        0
# 4                           0          0.001266                        0
#
#    Census_InternalPrimaryDisplayResolutionHorizontal  RtpStateBitfield  \
# 0                                             1366.0                 0
# 1                                             1366.0                 0
# 2                                             1366.0                 0
# 3                                             1366.0                 0
# 4                                             1280.0                 0
#
#    Census_ActivationChannel  GeoNameIdentifier  Census_OSUILocaleIdentifier  \
# 0                         2            0.01046                       0.1167
# 1                         0            0.17180                       0.3555
# 2                         3            0.17180                       0.3555
# 3                         0            0.17180                       0.3555
# 4                         0            0.03815                       0.1167
#
#    Census_OSEdition  AVProductsInstalled  \
# 0                 2                  2.0
# 1                 1                  2.0
# 2                 0                  1.0
# 3                 0                  1.0
# 4                 1                  1.0
#
#    Census_FirmwareManufacturerIdentifier  Census_OEMNameIdentifier  \
# 0                                0.08966                   0.10034
# 1                                0.01384                   0.10034
# 2                                0.10547                   0.10630
# 3                                0.10547                   0.10630
# 4                                0.04330                   0.10380
#
#    Census_SystemVolumeTotalCapacity  Census_OSVersion_0
# 0                          475799.0                   0
# 1                          461478.0                   0
# 2                          476438.0                   0
# 3                           37974.0                   0
# 4                          475955.0                   0

# %% [markdown]
# __Check file size__

# %%
from pathlib import Path
Path('Datasets/large_dataset.csv').stat().st_size / 1024**2
# Out:
# 106.19118595123291

# %% [markdown]
# __To Feather format__

# %%
# %%time
df.to_feather('Datasets/large_dataset.feather')
# Out:
# Wall time: 507 ms

# %% [markdown]
# __File size__

# %%
Path('Datasets/large_dataset.feather').stat().st_size / 1024**2
# Out:
# 35.60710334777832

# %%
df.shape
# Out:
# (1000000, 20)

# %% [markdown]
# That's a tremendous saving and the file loads back instantly.

# %% [markdown]
# __Read it back and record time__

# %%
# %%time
df = pd.read_feather('Datasets/large_dataset.feather')
df.head()
# Out:
# Wall time: 113 ms
#    HasTpm  Census_OSInstallLanguageIdentifier  LocaleEnglishNameIdentifier  \
# 0       1                              0.1160                     0.010284
# 1       1                              0.3562                     0.234700
# 2       1                              0.3562                     0.234700
# 3       1                              0.3562                     0.234700
# 4       1                              0.1160                     0.037380
#
#    EngineVersion  UacLuaenable  Census_MDC2FormFactor  \
# 0        0.41190             0                      1
# 1        0.43100             0                      1
# 2        0.02974             0                      1
# 3        0.41190             0                      1
# 4        0.41190             0                      0
#
#    Census_IsSecureBootEnabled  Census_OSVersion  Census_GenuineStateName  \
# 0                           1          0.039000                        0
# 1                           0          0.158400                        0
# 2                           0          0.023130                        2
# 3                           0          0.036440                        0
# 4                           0          0.001266                        0
#
#    Census_InternalPrimaryDisplayResolutionHorizontal  RtpStateBitfield  \
# 0                                             1366.0                 0
# 1                                             1366.0                 0
# 2                                             1366.0                 0
# 3                                             1366.0                 0
# 4                                             1280.0                 0
#
#    Census_ActivationChannel  GeoNameIdentifier  Census_OSUILocaleIdentifier  \
# 0                         2            0.01046                       0.1167
# 1                         0            0.17180                       0.3555
# 2                         3            0.17180                       0.3555
# 3                         0            0.17180                       0.3555
# 4                         0            0.03815                       0.1167
#
#    Census_OSEdition  AVProductsInstalled  \
# 0                 2                  2.0
# 1                 1                  2.0
# 2                 0                  1.0
# 3                 0                  1.0
# 4                 1                  1.0
#
#    Census_FirmwareManufacturerIdentifier  Census_OEMNameIdentifier  \
# 0                                0.08966                   0.10034
# 1                                0.01384                   0.10034
# 2                                0.10547                   0.10630
# 3                                0.10547                   0.10630
# 4                                0.04330                   0.10380
#
#    Census_SystemVolumeTotalCapacity  Census_OSVersion_0
# 0                          475799.0                   0
# 1                          461478.0                   0
# 2                          476438.0                   0
# 3                           37974.0                   0
# 4                          475955.0                   0

# %%
df.shape
# Out:
# (1000000, 20)

# %% [markdown]
# __Store as Parquet file__

# %%
# %%time
df.to_parquet('Datasets/large_dataset.parquet')
# Out:
# Wall time: 997 ms

# %% [markdown]
# __File size__

# %%
Path('Datasets/large_dataset.parquet').stat().st_size / 1024**2
# Out:
# 13.447064399719238

# %% [markdown]
# __Load it back and record time__

# %%
# %%time
df = pd.read_parquet('Datasets/large_dataset.parquet')
df.head()
# Out:
# Wall time: 233 ms
#    HasTpm  Census_OSInstallLanguageIdentifier  LocaleEnglishNameIdentifier  \
# 0       1                              0.1160                     0.010284
# 1       1                              0.3562                     0.234700
# 2       1                              0.3562                     0.234700
# 3       1                              0.3562                     0.234700
# 4       1                              0.1160                     0.037380
#
#    EngineVersion  UacLuaenable  Census_MDC2FormFactor  \
# 0        0.41190             0                      1
# 1        0.43100             0                      1
# 2        0.02974             0                      1
# 3        0.41190             0                      1
# 4        0.41190             0                      0
#
#    Census_IsSecureBootEnabled  Census_OSVersion  Census_GenuineStateName  \
# 0                           1          0.039000                        0
# 1                           0          0.158400                        0
# 2                           0          0.023130                        2
# 3                           0          0.036440                        0
# 4                           0          0.001266                        0
#
#    Census_InternalPrimaryDisplayResolutionHorizontal  RtpStateBitfield  \
# 0                                             1366.0                 0
# 1                                             1366.0                 0
# 2                                             1366.0                 0
# 3                                             1366.0                 0
# 4                                             1280.0                 0
#
#    Census_ActivationChannel  GeoNameIdentifier  Census_OSUILocaleIdentifier  \
# 0                         2            0.01046                       0.1167
# 1                         0            0.17180                       0.3555
# 2                         3            0.17180                       0.3555
# 3                         0            0.17180                       0.3555
# 4                         0            0.03815                       0.1167
#
#    Census_OSEdition  AVProductsInstalled  \
# 0                 2                  2.0
# 1                 1                  2.0
# 2                 0                  1.0
# 3                 0                  1.0
# 4                 1                  1.0
#
#    Census_FirmwareManufacturerIdentifier  Census_OEMNameIdentifier  \
# 0                                0.08966                   0.10034
# 1                                0.01384                   0.10034
# 2                                0.10547                   0.10630
# 3                                0.10547                   0.10630
# 4                                0.04330                   0.10380
#
#    Census_SystemVolumeTotalCapacity  Census_OSVersion_0
# 0                          475799.0                   0
# 1                          461478.0                   0
# 2                          476438.0                   0
# 3                           37974.0                   0
# 4                          475955.0                   0

# %% [markdown]
# __File Size on Disk__
#
# 1. CSV : 106mb
# 2. feather: 36mb
# 3. parquet: 13.4mb
#
# __Time to load__
#
# 1. CSV : 2.45s
# 2. feather: 113ms
# 3. parquet: 148ms
#
# __Parquet requires the least space but take a bit longer to load compared to feather. Feather is the fastest. Parquest requires least space.__

# %% [markdown]
#  <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>3. Working with HDF5</h2>
# </div>

# %% [markdown]
# HDF5 is a type of file storage that stores the data in a hierarchical structure. It is super fast to retrieve the data.
#
# we create a HDF5 store first and store the dataframes inside that in a hierarchy.

# %%
# !pip install tables==3.6.1

# %%
import numpy as np
from pandas import HDFStore, DataFrame

# %% [markdown]
# Create (or open) an hdf5 file and opens in append mode

# %%
hdf = HDFStore('Datasets/hdfstorage.h5', mode='a')
hdf
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: Datasets/hdfstorage.h5

# %% [markdown]
# __Create data__

# %%
df = DataFrame(np.random.rand(5,3), columns=('A','B','C'))
df.head()
# Out:
#           A         B         C
# 0  0.516243  0.026702  0.428357
# 1  0.459609  0.497303  0.039483
# 2  0.175030  0.419541  0.231524
# 3  0.142982  0.971437  0.663617
# 4  0.961227  0.887601  0.415256

# %% [markdown]
# __Store data to table__

# %%
hdf.put('df', df, format='table', data_columns=('A','B','C'))

# %%
hdf['df']
# Out:
#           A         B         C
# 0  0.516243  0.026702  0.428357
# 1  0.459609  0.497303  0.039483
# 2  0.175030  0.419541  0.231524
# 3  0.142982  0.971437  0.663617
# 4  0.961227  0.887601  0.415256

# %% [markdown]
# __Append to existing dataset__

# %%
hdf.append('df', df, format='table', data_columns=('A','B','C'))

# %% [markdown]
# __Check contents__

# %%
hdf['df']
# Out:
#           A         B         C
# 0  0.516243  0.026702  0.428357
# 1  0.459609  0.497303  0.039483
# 2  0.175030  0.419541  0.231524
# 3  0.142982  0.971437  0.663617
# 4  0.961227  0.887601  0.415256
# 0  0.516243  0.026702  0.428357
# 1  0.459609  0.497303  0.039483
# 2  0.175030  0.419541  0.231524
# 3  0.142982  0.971437  0.663617
# 4  0.961227  0.887601  0.415256

# %% [markdown]
# __Close connection__

# %%
hdf.close()

# %% [markdown]
# __Read from Store again__

# %%
from pandas import read_hdf
df = read_hdf('Datasets/hdfstorage.h5', 'df')
df
# Out:
#           A         B         C
# 0  0.516243  0.026702  0.428357
# 1  0.459609  0.497303  0.039483
# 2  0.175030  0.419541  0.231524
# 3  0.142982  0.971437  0.663617
# 4  0.961227  0.887601  0.415256
# 0  0.516243  0.026702  0.428357
# 1  0.459609  0.497303  0.039483
# 2  0.175030  0.419541  0.231524
# 3  0.142982  0.971437  0.663617
# 4  0.961227  0.887601  0.415256

# %% [markdown]
# If you want to apply a rule when importing, like subsampling or importing select columns, its very direct.

# %%
df = read_hdf('Datasets/hdfstorage.h5', 'df', where=['A>.5'], columns=['A','B'])
df
# Out:
#           A         B
# 0  0.516243  0.026702
# 4  0.961227  0.887601
# 0  0.516243  0.026702
# 4  0.961227  0.887601

# %% [markdown]
# __Store multiple tables under hierarchical directories inside HDFStore__

# %%
hdf = HDFStore('Datasets/hdfstorage.h5')

# %%
hdf.put('sales/t1', pd.DataFrame(np.random.rand(20,5)))
hdf.put('sales/t2', pd.DataFrame(np.random.rand(10,3)))
hdf.put('catalog/t1', pd.DataFrame(np.random.rand(15,2)))

# %% [markdown]
# __See the tables__

# %%
hdf.keys()
# Out:
# ['/df', '/sales/t1', '/sales/t2', '/large/df', '/catalog/t1']

# %%
print(hdf.info())
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: Datasets/hdfstorage.h5
# /catalog/t1            frame        (shape->[15,2])
# /df                    frame_table  (typ->appendable,nrows->10,ncols->3,indexers->[index],dc->[A,B,C])
# /large/df              frame        (shape->[1000000,20])
# /sales/t1              frame        (shape->[20,5])
# /sales/t2              frame        (shape->[10,3])

# %% [markdown]
# __Put Large Data__

# %%
df = pd.read_csv('Datasets/large_dataset.csv')
hdf.put('large/df', df)

# %%
hdf.close()

# %% [markdown]
# __Read it back and time it__

# %%
# %%time
hdf = HDFStore('Datasets/hdfstorage.h5')
# Out:
# Wall time: 10 ms

# %%
# %%time
df = hdf['large/df']  # address in hdfS
df.head()
# Out:
# Wall time: 530 ms
#    HasTpm  Census_OSInstallLanguageIdentifier  LocaleEnglishNameIdentifier  \
# 0       1                              0.1160                     0.010284
# 1       1                              0.3562                     0.234700
# 2       1                              0.3562                     0.234700
# 3       1                              0.3562                     0.234700
# 4       1                              0.1160                     0.037380
#
#    EngineVersion  UacLuaenable  Census_MDC2FormFactor  \
# 0        0.41190             0                      1
# 1        0.43100             0                      1
# 2        0.02974             0                      1
# 3        0.41190             0                      1
# 4        0.41190             0                      0
#
#    Census_IsSecureBootEnabled  Census_OSVersion  Census_GenuineStateName  \
# 0                           1          0.039000                        0
# 1                           0          0.158400                        0
# 2                           0          0.023130                        2
# 3                           0          0.036440                        0
# 4                           0          0.001266                        0
#
#    Census_InternalPrimaryDisplayResolutionHorizontal  RtpStateBitfield  \
# 0                                             1366.0                 0
# 1                                             1366.0                 0
# 2                                             1366.0                 0
# 3                                             1366.0                 0
# 4                                             1280.0                 0
#
#    Census_ActivationChannel  GeoNameIdentifier  Census_OSUILocaleIdentifier  \
# 0                         2            0.01046                       0.1167
# 1                         0            0.17180                       0.3555
# 2                         3            0.17180                       0.3555
# 3                         0            0.17180                       0.3555
# 4                         0            0.03815                       0.1167
#
#    Census_OSEdition  AVProductsInstalled  \
# 0                 2                  2.0
# 1                 1                  2.0
# 2                 0                  1.0
# 3                 0                  1.0
# 4                 1                  1.0
#
#    Census_FirmwareManufacturerIdentifier  Census_OEMNameIdentifier  \
# 0                                0.08966                   0.10034
# 1                                0.01384                   0.10034
# 2                                0.10547                   0.10630
# 3                                0.10547                   0.10630
# 4                                0.04330                   0.10380
#
#    Census_SystemVolumeTotalCapacity  Census_OSVersion_0
# 0                          475799.0                   0
# 1                          461478.0                   0
# 2                          476438.0                   0
# 3                           37974.0                   0
# 4                          475955.0                   0

# %%
hdf.close()

# %% [markdown]
# __Using read_hdf__

# %%
# %%time
hdf = read_hdf('Datasets/hdfstorage.h5', key='large/df', mode='a')
hdf

# %% [markdown]
#  <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>4. Reading a Big File in Chunks</h2>
# </div>

# %% [markdown]
# __When to use__
#
# Sometimes you might not want to read the full file as a dataframe. Instead, you want to select specific rows and columns to go in your dataframe.
#
# Ex: How to extract all the records with dose > 0.5? (it could be any logic. Ex: extract the largest in each chunk).
#
# We read all records, but only the filtered records make it to dataframe, thus saving system memory. Useful especially for large datasets.

# %%
import pandas as pd

# %%
df_chunker = pd.read_csv("Datasets/ToothGrowth.txt", chunksize=10)
print(df_chunker)
# Out:
# <pandas.io.parsers.TextFileReader object at 0x000002107A75FF88>

# %%
pd.read_csv("Datasets/ToothGrowth.txt").head()
# Out:
#     len supp  dose
# 0   4.2   VC   0.5
# 1  11.5   VC   0.5
# 2   7.3   VC   0.5
# 3   5.8   VC   0.5
# 4   6.4   VC   0.5

# %% [markdown]
# `df_chunker` can be iterated only once.

# %%
# Dose > .5 and Every 5th item
master = []

for i, df in enumerate(df_chunker):
    df = df.loc[(df.dose > .5) & (df.index % 5 == 0), :]
    if df.shape[0] >= 1:
        master.append(df)
    
master
# Out:
# [     len supp  dose
#  10  16.5   VC     1
#  15  17.3   VC     1,
#       len supp  dose
#  20  23.6   VC     2
#  25  32.5   VC     2,
#       len supp  dose
#  40  19.7   OJ     1
#  45  25.2   OJ     1,
#       len supp  dose
#  50  25.5   OJ     2
#  55  30.9   OJ     2]

# %% [markdown]
# Combine all the dataframes in the list.

# %%
pd.concat(master)
# Out:
#      len supp  dose
# 10  16.5   VC     1
# 15  17.3   VC     1
# 20  23.6   VC     2
# 25  32.5   VC     2
# 40  19.7   OJ     1
# 45  25.2   OJ     1
# 50  25.5   OJ     2
# 55  30.9   OJ     2

# %% [markdown]
# ### Mini Challenge
#
# Use chunking to extract first 50 `EngineVersion` in the dataset that has 2 `AVProductsInstalled` and `Census_OSEdition` = 0.
#
# ```python
# path = 'Datasets/large_dataset.csv'
# ```

# %%
import pandas as pd
import numpy as np

# %%
path = 'Datasets/large_dataset.csv'

# %%
df_chunker = pd.read_csv(path, chunksize=100)
print(df_chunker)
# Out:
# <pandas.io.parsers.TextFileReader object at 0x000002107A829608>

# %%
# Every 5th row that has atleast 2 AVProductsInstalled
master = []
engines_extracted = 0

for i, df in enumerate(df_chunker):
    df = df.loc[(df.AVProductsInstalled >= 2) & (df.Census_OSEdition == 0), "EngineVersion"]
    if (df.shape[0] >= 1):
        if engines_extracted <= 50:
            master.append(df)
            engines_extracted += df.shape[0]
        else:
            print("50 EngineVersions extracted")
            break
        
master
# Out:
# 50 EngineVersions extracted
# [31    0.411900
#  47    0.411900
#  49    0.431000
#  52    0.015270
#  60    0.411900
#  62    0.431000
#  83    0.005165
#  99    0.411900
#  Name: EngineVersion, dtype: float64,
#  105    0.017970
#  112    0.411900
#  178    0.411900
#  179    0.007935
#  Name: EngineVersion, dtype: float64,
#  227    0.005165
#  230    0.431000
#  243    0.431000
#  256    0.001086
#  264    0.431000
#  268    0.004078
#  269    0.431000
#  286    0.411900
#  Name: EngineVersion, dtype: float64,
#  322    0.431000
#  324    0.411900
#  328    0.001714
#  370    0.411900
#  376    0.411900
#  383    0.431000
#  388    0.411900
#  396    0.411900
#  Name: EngineVersion, dtype: float64,
#  428    0.431000
#  437    0.005226
#  455    0.431000
#  461    0.431000
#  470    0.431000
#  474    0.015270
#  487    0.431000
#  492    0.431000
#  Name: EngineVersion, dtype: float64,
#  509    0.41190
#  526    0.41190
#  545    0.43100
#  551    0.43100
#  567    0.41190
#  598    0.02391
#  Name: EngineVersion, dtype: float64,
#  604    0.431000
#  610    0.431000
#  635    0.004078
#  652    0.431000
#  661    0.411900
#  678    0.431000
#  685    0.015270
#  696    0.411900
#  Name: EngineVersion, dtype: float64,
#  732    0.43100
#  774    0.01527
#  778    0.43100
#  791    0.41190
#  Name: EngineVersion, dtype: float64]

# %%
df_out = pd.concat(master)
df_out
# Out:
# 31     0.411900
# 47     0.411900
# 49     0.431000
# 52     0.015270
# 60     0.411900
# 62     0.431000
# 83     0.005165
# 99     0.411900
# 105    0.017970
# 112    0.411900
# 178    0.411900
# 179    0.007935
# 227    0.005165
# 230    0.431000
# 243    0.431000
# 256    0.001086
# 264    0.431000
# 268    0.004078
# 269    0.431000
# 286    0.411900
# 322    0.431000
# 324    0.411900
# 328    0.001714
# 370    0.411900
# 376    0.411900
# 383    0.431000
# 388    0.411900
# 396    0.411900
# 428    0.431000
# 437    0.005226
# 455    0.431000
# 461    0.431000
# 470    0.431000
# 474    0.015270
# 487    0.431000
# 492    0.431000
# 509    0.411900
# 526    0.411900
# 545    0.431000
# 551    0.431000
# 567    0.411900
# 598    0.023910
# 604    0.431000
# 610    0.431000
# 635    0.004078
# 652    0.431000
# 661    0.411900
# 678    0.431000
# 685    0.015270
# 696    0.411900
# 732    0.431000
# 774    0.015270
# 778    0.431000
# 791    0.411900
# Name: EngineVersion, dtype: float64

# %%
df_out.shape
# Out:
# (54,)

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>5. Load in Database and read from it</h2>
# </div>

# %% [markdown]
# When you have a large file that cannot be loaded to memory,  load it to a database in chunks and then query from it using pandas. [link](https://www.youtube.com/watch?v=xKMyk4wDHnQ)
#
# [SQLite Doc](https://docs.python.org/3/library/sqlite3.html)

# %%
import numpy as np
import pandas as pd
import sqlite3

# %% [markdown]
# __Steps__:
#
# 1. Create connection to database.
# 2. Load the csv to database in chunks
# 3. Use SQL Query to load data to pandas

# %%
filepath = 'Datasets/large_dataset.csv'
pd.read_csv(filepath, nrows=2)
# Out:
#    HasTpm  Census_OSInstallLanguageIdentifier  LocaleEnglishNameIdentifier  \
# 0       1                              0.1160                     0.010284
# 1       1                              0.3562                     0.234700
#
#    EngineVersion  UacLuaenable  Census_MDC2FormFactor  \
# 0         0.4119             0                      1
# 1         0.4310             0                      1
#
#    Census_IsSecureBootEnabled  Census_OSVersion  Census_GenuineStateName  \
# 0                           1            0.0390                        0
# 1                           0            0.1584                        0
#
#    Census_InternalPrimaryDisplayResolutionHorizontal  RtpStateBitfield  \
# 0                                             1366.0                 0
# 1                                             1366.0                 0
#
#    Census_ActivationChannel  GeoNameIdentifier  Census_OSUILocaleIdentifier  \
# 0                         2            0.01046                       0.1167
# 1                         0            0.17180                       0.3555
#
#    Census_OSEdition  AVProductsInstalled  \
# 0                 2                  2.0
# 1                 1                  2.0
#
#    Census_FirmwareManufacturerIdentifier  Census_OEMNameIdentifier  \
# 0                                0.08966                   0.10034
# 1                                0.01384                   0.10034
#
#    Census_SystemVolumeTotalCapacity  Census_OSVersion_0
# 0                          475799.0                   0
# 1                          461478.0                   0

# %% [markdown]
# __Load the file in database without loading the full file in pandas__

# %%
# create connection
con = sqlite3.connect('files.db')

# %% [markdown]
# __Run SQL queries directly__

# %%
cur = con.cursor()
cur

# %%
# Execute query. sqlite_master is a system table that contains all table names in sqlite db.
cur.execute("SELECT name FROM sqlite_master")

# %%
# Show the query
print(cur.fetchall())
# Out:
# [('large_dataset',), ('ix_large_dataset_index',)]

# %% [markdown]
# Drop Table if any table is already present

# %%
# Execute query
cur.execute("drop table large_dataset;")

# %%
# Show the query results
print(cur.fetchall())
# Out:
# []

# %% [markdown]
# Commit changes

# %%
# commit the changes
con.commit()

# %% [markdown]
# Add data to database table by reading in chunks from pandas and upload it.

# %%
# Add data to sqlite table in chunks
chunksize = 5000

for i, df in enumerate(pd.read_csv(filepath, chunksize=chunksize, iterator=True)):
    df = df.rename(columns = {c: c.replace(' ', '').lower() for c in df.columns})
    df['chunk'] = i
    
    df.to_sql('large_dataset', con, if_exists='append')
    if not i % 50: print(f"Chunk: {i} Loaded.")
# Out:
# Chunk: 0 Loaded.
# Chunk: 50 Loaded.
# Chunk: 100 Loaded.
# Chunk: 150 Loaded.

# %% [markdown]
# Read data from database

# %%
# Read data from table
df = pd.read_sql_query('SELECT * FROM large_dataset WHERE HASTPM=0', con)
df.head()
# Out:
#    index  hastpm  census_osinstalllanguageidentifier  \
# 0     94       0                             0.02843
# 1    229       0                             0.35620
# 2    240       0                                 NaN
# 3    281       0                                 NaN
# 4    366       0                             0.02267
#
#    localeenglishnameidentifier  engineversion  uacluaenable  \
# 0                      0.02031        0.02974             0
# 1                      0.23470        0.43100             0
# 2                      0.23470        0.41190             0
# 3                      0.05050        0.43100             0
# 4                      0.01817        0.43100             0
#
#    census_mdc2formfactor  census_issecurebootenabled  census_osversion  \
# 0                      0                           0          0.003431
# 1                      1                           0          0.002861
# 2                      1                           0          0.004590
# 3                      1                           0          0.000722
# 4                      0                           0          0.004513
#
#    census_genuinestatename  ...  census_activationchannel  geonameidentifier  \
# 0                        0  ...                         0            0.02072
# 1                        0  ...                         0            0.17180
# 2                        1  ...                         0            0.17180
# 3                        0  ...                         0            0.04752
# 4                        0  ...                         0            0.01823
#
#    census_osuilocaleidentifier  census_osedition  avproductsinstalled  \
# 0                      0.02843                 1                  2.0
# 1                      0.35550                 0                  1.0
# 2                      0.35550                 1                  1.0
# 3                      0.05590                 1                  1.0
# 4                      0.02272                 1                  1.0
#
#    census_firmwaremanufactureridentifier  census_oemnameidentifier  \
# 0                                 0.0433                  0.103800
# 1                                 0.1380                  0.144400
# 2                                 0.3025                  0.002142
# 3                                 0.3025                  0.002142
# 4                                 0.3025                  0.007965
#
#    census_systemvolumetotalcapacity  census_osversion_0  chunk
# 0                          142625.0                   0      0
# 1                          144397.0                   0      0
# 2                          136795.0                   0      0
# 3                          102400.0                   0      0
# 4                          176389.0                   0      0
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (12149, 22)

# %% [markdown]
# __Close connection__

# %%
con.close()
