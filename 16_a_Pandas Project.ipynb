# %% [markdown]
# <div style="color:#006666; padding:0px 10px; border-radius:5px; font-size:18px; text-align:center"><h1 style='margin:10px 5px'>Pandas Project</h1>
# </div>
# <hr>
# <div style="color:#006666; text-align:right">
# © Copyright Machine Learning Plus
# <br>
# Visit machinelearningplus.com for more information.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>1. Data</h2>
# </div>

# %% [markdown]
# The data is hosted by the Global Health Observatory (GHO) data repository under World Health Organization (WHO) which keeps track of the health status as well as many other related factors for all countries.
#
# The dataset related to life expectancy, health factors for 193 countries has been collected from the same WHO data repository website and its corresponding economic data was collected from United Nation website.
#
# Each row in the dataset represents a country-year pair and corresponding health and economic factors.

# %% [markdown]
# |Field|Description|
# |---:|:---|
# |Country|Country|
# |Year|Year|
# |Status|Developed or Developing status|
# |Life expectancy|Life Expectancy in age|
# |Adult Mortality|Adult Mortality Rates of both sexes (probability of dying between 15 and 60 years per 1000 population)|
# |infant deaths|Number of Infant Deaths per 1000 population|
# |Alcohol|Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol)|
# |percentage expenditure|Expenditure on health as a percene of Gross Domestic Product per capita(%)|
# |Hepatitis B|Hepatitis B (HepB) immunization coverage among 1-year-olds (%)|
# |Measles|Measles - number of reported cases per 1000 population|
# |BMI|Average Body Mass Index of entire population|
# |under-five deaths|Number of under-five deaths per 1000 population|
# |Polio|Polio (Pol3) immunization coverage among 1-year-olds (%)|
# |Total expenditure|General government expenditure on health as a percene of total government expenditure (%)|
# |Diphtheria|Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)|
# |HIV/AIDS|Deaths per 1 000 live births HIV/AIDS (0-4 years)|
# |GDP|Gross Domestic Product per capita (in USD)|
# |Population|Population of the country|
# |thinness 1-19 years|Prevalence of thinness among children and adolescents for Age 10 to 19 (%)|
# |thinness 5-9 years|Prevalence of thinness among children for Age 5 to 9(%)|
# |Income composition of resources|Income composition of resources|
# |Schooling|Number of years of Schooling(years)|

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006666; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>2. Tasks</h2>
# </div>
#
# 1. Display the first five rows and make it show all the columns without truncating.
# 2. Display all the columns and their types
# 3. Extract the number of rows and columns present in the data
# 4. Does any of columns have extra spaces in the name. If so, remove the extra spaces
# 5. Get the summary of the data
# 6. Are there any missing values in the data? If so, which column has the 2nd most missing values
# 7. Treat the missing values
# 8. Are there any outliers in the 'Life Expectancy' column in the data.
# 9. How many countries have the status as developed and developing respectively
# 10. Which country has the highest BMI (average)
# 11. Who has higher life expectancy, developed or developing?
# 12. Which year experienced the lowest adult mortality
# 13. What is the average life expectancy when the GDP is above 600

# %%
# Import libraries
import pandas as pd

# %%
# Write code here
df = pd.read_csv("Datasets/Life Expectancy Data.csv")
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# ### Q1. Display the first five rows and make it show all the columns without truncating.

# %%
# Write code here

# %% [markdown]
# ### Q2. Display all the columns and their types

# %%
# Write code here

# %% [markdown]
# ### Q3 Extract the number of rows and columns present in the data

# %%
# Write code here

# %% [markdown]
# ### Q4. Does any of columns have extra spaces in the name. If so, remove the extra spaces

# %%
# Write code here

# %% [markdown]
# ### Q5. Get the summary of the data

# %%
# Write code here

# %% [markdown]
# ### Q6. Are there any missing values in the data? If so, which columns have more than 10% missing values?

# %%
# Write code here

# %% [markdown]
# ### Q7. Treat the missing values by replacing them with the column median

# %%
# Write code here

# %% [markdown]
# ### Q8. How many countries have the status as developed and developing respectively

# %%
# Write code here

# %% [markdown]
# ### Q9. Which country has the highest BMI (average)

# %%
# Write code here

# %% [markdown]
# ### Q10. Who has higher life expectancy, developed or developing countries?

# %%
# Write code here

# %% [markdown]
# ### Q11. Which year experienced the lowest adult mortality

# %%
# Write code here

# %% [markdown]
# ### Q12. What is the average life expectancy when the GDP is above 600

# %%
# Write code here
